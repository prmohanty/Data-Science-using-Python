# %% [markdown]
# # Regression using Python
#
# Priyaranjan Mohanty

# %% [markdown]
# # Machine Learning : Supervised Machine Learning
#
#
# In supervised learning, an algorithm is employed to learn the mapping function from the input variable (x) to the output variable (y); that is y = f(X).
#
# The objective of such a problem is to approximate the mapping function (f) as accurately as possible such that whenever there is a new input data (x), the output variable (y) for the dataset can be predicted.
#
# Here is a chart that shows the different groupings of machine learning:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Classification :
#
# classification algorithms attempt to estimate the mapping function (f) from the input variables (x) to discrete or categorical output variables (y).
#
# In this case, y is a category that the mapping function predicts. If provided with a single or several input variables, a classification model will attempt to predict the value of a single or several conclusions.

# %% [markdown]
# ## Regression :
#
# In machine learning, regression algorithms attempt to estimate the mapping function (f) from the input variables (x) to numerical or continuous output variables (y).
#
# In this case, y is a real value, which can be an integer or a floating point value. Therefore, regression prediction problems are usually quantities or sizes.
#
# For example, when provided with a dataset about houses, and you are asked to predict their prices, that is a regression task because price will be a continuous output.

# %% [markdown]
# # Part 1 : Linear Regression - Concept

# %% [markdown]
# ## Linear Regression
#
# #### What is Linear :
# Linearity is the property of a mathematical relationship or function which means that it can be graphically represented as a straight line.
#
# #### What is Regression?
# Regression analysis is a form of predictive modelling technique which investigates the relationship between a dependent and independent variable.
#
# ![image.png](attachment:image.png)
#
#
# #### linear regression
# It is a linear approach to modelling the relationship between a scalar response (or dependent variable) and one or more explanatory variables (or independent variables).
#
# #### Simple Linear Regression / Multiple Linear Regression
# When there is only one independent feature it is called Uni-variate Linear Regression or Simple Linear Regression and if there are multiple features, it is called Multiple Linear Regression.
#
#
# The linear regression model can be represented by the following equation
#               Y = θ₀ + θ₁x₁.....+θₙxₙ
#
# Y is the predicted value
# θ₀ is the bias term.
# θ₁,…,θₙ are the model parameters
# x₁, x₂,…,xₙ are the feature values.

# %%
# imports

import numpy as np

import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, r2_score

# %%
# generate random data-set

np.random.seed(12)

x = np.random.rand(100, 1)

y = 2 + 3 * x + np.random.rand(100, 1)

# %%
x
# Out:
# array([[0.15416284],
#        [0.7400497 ],
#        [0.26331502],
#        [0.53373939],
#        [0.01457496],
#        [0.91874701],
#        [0.90071485],
#        [0.03342143],
#        [0.95694934],
#        [0.13720932],
#        [0.28382835],
#        [0.60608318],
#        [0.94422514],
#        [0.85273554],
#        [0.00225923],
#        [0.52122603],
#        [0.55203763],
#        [0.48537741],
#        [0.76813415],
#        [0.16071675],
#        [0.76456045],
#        [0.0208098 ],
#        [0.13521018],
#        [0.11627302],
#        [0.30989758],
#        [0.67145265],
#        [0.47122978],
#        [0.8161683 ],
#        [0.28958678],
#        [0.73312598],
#        [0.70262236],
#        [0.32756948],
#        [0.33464753],
#        [0.97805808],
#        [0.62458211],
#        [0.95031352],
#        [0.76747565],
#        [0.82500925],
#        [0.4066403 ],
#        [0.45130841],
#        [0.40063163],
#        [0.99513816],
#        [0.17756418],
# ...

# %%
# plot

plt.scatter(x,y,s=10)

plt.xlabel('x')

plt.ylabel('y')

plt.show()

# %% [markdown]
# #### Linear Regression Model
#
# Finding the parameters so that a 'Best Fit ' straight line can be drawn which represents the relationship between X & Y variables.
#
# #### What is best fit line ?
#
# The line for which the the error between the predicted values and the observed values is minimum is called the best fit line or the regression line. These errors are also called as residuals. The residuals can be visualized by the vertical lines from the observed data value to the regression line.
#
# ![image.png](attachment:image.png)
#
#
# Why do we take the square of the residuals and not the absolute value of the residuals ? We want to penalize the points which are farther from the regression line much more than the points which lie close to the line.
#
# Why are we dividing by m : Thats to find the Average Error and making the error term independent of number of points being considered for determining the regression line
#
# Why are we divinding by 2 : The reason is that when you take the derivative of your cost function, the square becomes a 2*(expression) and the 1/2 cancels out the 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Our objective is to find the model parameters so that the cost function is minimum.
#
# Now the question arises, how do we reduce the error value.
# Well, this can be done by using Gradient Descent.
# The main goal of Gradient descent is to minimize the cost function.
#
# Gradient descent has an analogy in which we have to imagine ourselves at the top of a mountain valley and left stranded and blindfolded, our objective is to reach the bottom of the hill. Feeling the slope of the terrain around you is what everyone would do. Well, this action is analogous to calculating the gradient descent, and taking a step is analogous to one iteration of the update to the parameters.
#
# ![image.png](attachment:image.png)
#
# #### Learning Rate
#
# Choosing a perfect learning rate is a very important task as it depends on how large of a step we take downhill during each iteration. If we take too large of a step, we may step over the minimum. However, if we take small steps, it will require many iterations to arrive at the minimum.

# %% [markdown]
# ### sckit-learn implementation

# %%
# Model initialization

regression_model = LinearRegression()

# %%
# Fit the data(train the model)

regression_model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regression_model.coef_
# Out:
# array([[3.0620223]])

# %%
regression_model.intercept_
# Out:
# array([2.47674563])

# %%
#  y = 3.0620223 * x + 2.47674563

# %%
# Predict

y_predicted = regression_model.predict(x)

# %%
y_predicted
# Out:
# array([[2.94879569],
#        [4.7427943 ],
#        [3.28302208],
#        [4.11106755],
#        [2.52137449],
#        [5.28996946],
#        [5.2347546 ],
#        [2.57908279],
#        [5.40694584],
#        [2.89688363],
#        [3.34583438],
#        [4.33258586],
#        [5.36798405],
#        [5.08784087],
#        [2.48366346],
#        [4.07275135],
#        [4.16709717],
#        [3.96298209],
#        [4.82878954],
#        [2.96886391],
#        [4.81784678],
#        [2.5404657 ],
#        [2.89076221],
#        [2.8327762 ],
#        [3.42565895],
#        [4.5327486 ],
#        [3.91966172],
#        [4.97587116],
#        [3.36346682],
#        [4.72159372],
#        [4.62819095],
#        [3.47977067],
#        [3.50144383],
#        [5.47158128],
#        [4.38922998],
#        [5.38662683],
#        [4.82677319],
#        [5.00294236],
#        [3.7218873 ],
#        [3.85866205],
#        [3.70348861],
#        [5.52388087],
#        [3.0204511 ],
# ...

# %%
# model evaluation

rmse = mean_squared_error(y, y_predicted)

r2 = r2_score(y, y_predicted)

# %%
# printing values

print('Slope:' ,regression_model.coef_)

print('Intercept:', regression_model.intercept_)

print('Root mean squared error: ', rmse)

print('R2 score: ', r2)
# Out:
# Slope: [[3.0620223]]
# Intercept: [2.47674563]
# Root mean squared error:  0.08231038377705556
# R2 score:  0.9115284277518596

# %% [markdown]
# #### What Is R-squared?
# R-squared is a statistical measure of how close the data are to the fitted regression line. It is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression.
#
# The definition of R-squared is fairly straight-forward;
#
# it is the percentage of the response variable variation that is explained by a linear model. Or:
# R-squared = Explained variation / Total variation
# R-squared is always between 0 and 100%:
#
# 0% indicates that the model explains none of the variability of the response data around its mean.
#
# 100% indicates that the model explains all the variability of the response data around its mean.
#
# In general, the higher the R-squared, the better the model fits your data. However, there are important conditions for this guideline that I’ll talk about both in this post and my next post.

# %%
# plotting values



# data points

plt.scatter(x, y, s=10)

plt.xlabel('x')

plt.ylabel('y')



# predicted values

plt.plot(x, y_predicted, color='r')

plt.show()

# %% [markdown]
# # Part 2 : Linear Regression - Implementation [ Case Study ]

# %% [markdown]
# ### Case Study Overview -
#
# We will take the Housing dataset which contains information about different houses in Boston.
#
# There are 506 samples and 13 feature variables in this dataset. The objective is to predict the value of prices of the house using the given features.

# %% [markdown]
# #### Step 1 : We will import the required libraries.

# %%
import numpy as np                       # Numerical Python for Array computation 

import matplotlib.pyplot as plt          # For Plotting / Visualization 

import pandas as pd                      # For Data Wrangling / Processing 

import seaborn as sns                    # For Visualization

# %% [markdown]
# #### Step 2 : we will load the housing data from the scikit-learn library .

# %%
# Load the Boston Dataset 

from sklearn.datasets import load_boston

boston_dataset = load_boston()

# %% [markdown]
# #### Step 3 : Perform EDA ( Exploratory Data Analysis ) on the Boston Dataset

# %%
# Check the type of the Dataset 

type(boston_dataset)
# Out:
# sklearn.utils.Bunch

# %%
# Print the Description of the Dataset 

print(boston_dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
# View the DATA component of the Dataset ( which are the Independent / Predictor Variables)

boston_dataset.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
# Check the shape of the Datset ( which is to check # of Rows & Columns of the Dataset )

boston_dataset.data.shape
# Out:
# (506, 13)

# %%
# Get the names of all Predictor Variables 

boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
# Get the count of number of Predictor variables 

len(boston_dataset.feature_names)
# Out:
# 13

# %%
# Check the content of the Response Variable

boston_dataset.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
# Check the shape of the Response Variable

boston_dataset.target.shape
# Out:
# (506,)

# %% [markdown]
# #### Step 4 : Convert the Dataset into a Pandas Dataframe
#
# Note that the dataset loaded in the previous step is in Numpy Array form
#
# In this step , we will convert it into Pandas Dataframe

# %%
# Create DataFrame , containing only Predictor variables 

Boston_DF = pd.DataFrame(boston_dataset.data, 
                         columns=boston_dataset.feature_names)

# %%
# View the first 5 observations / record in the Boston dataframe created 

Boston_DF.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# Get the statistical Summary of each columns in the Dataframe 

Boston_DF.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Get the Structural information abt the 

Boston_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %% [markdown]
# #### Step 4.1 : Add the Response variable MDEV to the Boston Dataframe created

# %%
Boston_DF['MEDV'] = boston_dataset.target

# %%
Boston_DF.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# #### Step 4.2 : Now , lets check for Missing value in any columns

# %%
Boston_DF.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# #### Step 4.3 : Draw a Correlation Heatmap
#
# The correlation coefficient ranges from -1 to 1.
#
# If the value is close to 1, it means that there is a strong positive correlation between the two variables.
#
# When it is close to -1, the variables have a strong negative correlation.
#
# When it is close to 0, the variables have a No or very very Low  correlation.

# %%
correlation_matrix = Boston_DF.corr().round(1)

# annot = True to print the values inside the square

sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# #### MultiCollinearity - Why its a Problem
#
# Consider the simplest case where Y is regressed against X and Z and where X and Z are highly positively correlated. Then the effect of
# X on Y is hard to distinguish from the effect of Z on Y because any increase in X tends to be associated with an increase in Z.
#
# Another way to look at this is to consider the equation. If we write Y=b0+b1X+b2Z+e , then the coefficient b1 is the increase in Y
# for every unit increase in X while holding Z constant.
#
# But in practice, it is often impossible to hold Z constant and the positive correlation between X and Z mean that a unit increase in
# X is usually accompanied by some increase in Z at the same time.

# %% [markdown]
# #### Correlation Between Response Variable and Predictor Variables
#
# To fit a linear regression model, we select those features which have a high correlation with our target variable MEDV. By looking at the correlation matrix we can see that RM has a strong positive correlation with MEDV (0.7) where as LSTAT has a high negative correlation with MEDV(-0.74).

# %% [markdown]
# Based on the above observations we will use Predictor Variables RM and LSTAT as our features.
#
# Using a scatter plot let’s see how these features vary with MEDV.

# %%
plt.figure(figsize=(20, 5))



features = ['LSTAT', 'RM']

target = Boston_DF['MEDV']



for i, col in enumerate(features):

    plt.subplot(1, len(features) , i+1)

    x = Boston_DF[col]

    y = target

    plt.scatter(x, y, marker='o')

    plt.title(col)

    plt.xlabel(col)

    plt.ylabel('MEDV')

# %% [markdown]
# #### Observations:
#
# The prices increase as the value of RM increases linearly.
#
#
# The prices tend to decrease with an increase in LSTAT. Though it doesn’t look to be following exactly a linear line.

# %% [markdown]
# #### Step 5 : Preparing the data for training the model

# %%
# We can concatenate the LSTAT and RM columns using np.c_ provided by the numpy library.

X_Independent_Vars = pd.DataFrame(np.c_[Boston_DF['LSTAT'], 
                                        Boston_DF['RM']],
                                  columns = ['LSTAT','RM'])

Y_Dependent_Var = Boston_DF['MEDV']

# %%
X_Independent_Vars.head()
# Out:
#    LSTAT     RM
# 0   4.98  6.575
# 1   9.14  6.421
# 2   4.03  7.185
# 3   2.94  6.998
# 4   5.33  7.147

# %% [markdown]
# #### Step 5.1 : Splitting the Data into Training & Test Dataset
#
# Training Set : 80% of the Data
#
# Testing Set : 20% of the Data

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, Y_train, Y_test = train_test_split(X_Independent_Vars, 
                                                    Y_Dependent_Var, 
                                                    test_size = 0.2, 
                                                    random_state=5)

print(X_train.shape)

print(X_test.shape)

print(Y_train.shape)

print(Y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %% [markdown]
# #### Step 6 : Training the model ( Regression Model )
#
# We use scikit-learn’s LinearRegression to train our model on both the training and test sets.

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error


Linear_Model = LinearRegression()

Linear_Model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
Linear_Model.intercept_
# Out:
# 2.7362403426066138

# %%
Linear_Model.coef_
# Out:
# array([-0.71722954,  4.58938833])

# %% [markdown]
# #### Step 7 : Testing / Validating the model ( Regression Model )
#
# We will evaluate our model using RMSE and R2-score

# %%
# model evaluation for training set

y_train_predict = Linear_Model.predict(X_train)

rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))

r2 = r2_score(Y_train, y_train_predict)

# %%
print("The model performance for training set")

print("--------------------------------------")

print('RMSE is {}'.format(rmse))

print('R2 score is {}'.format(r2))

print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 5.6371293350711955
# R2 score is 0.6300745149331701

# %%
# model evaluation for testing set

y_test_predict = Linear_Model.predict(X_test)

rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

r2 = r2_score(Y_test, y_test_predict)



print("The model performance for testing set")

print("--------------------------------------")

print('RMSE is {}'.format(rmse))

print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 5.13740078470291
# R2 score is 0.6628996975186954

# %% [markdown]
# # Part 3 : Polynomial Regression - Concept

# %% [markdown]
# #### Why Polynomial Regression
#
# Linear regression requires the relation between the dependent variable and the independent variable to be linear. What if the distribution of the data was more complex as shown in the below figure? Can linear models be used to fit non-linear data? How can we generate a curve that best captures the data as shown below?
# ![image.png](attachment:image.png)
# #### That's where Polynomial Regression come into action

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(0)

X_Data = 2 - 3 * np.random.normal(0, 1, 20)

Y_Data = ( X_Data - 2 * (X_Data ** 2) + 0.5 * (X_Data ** 3) + 
           np.random.normal(-3, 3, 20) )

# %%
X_Data.shape
# Out:
# (20,)

# %%
# transforming the data to include another axis

X_Data = X_Data.reshape((20,1))

Y_Data = Y_Data.reshape((20,1))

# %%
plt.scatter(X_Data, Y_Data, s=10)

# %%
# Build Simple Linear Regression

Linear_model = LinearRegression()
Linear_model.fit(X_Data, Y_Data)
Y_pred = Linear_model.predict(X_Data)



plt.scatter(X_Data, Y_Data, s=10)

plt.plot(X_Data, Y_pred, color='r')

plt.show()

# %% [markdown]
# #### under-fitting
#
# Above , We can see that the straight line is unable to capture the patterns in the data. This is an example of under-fitting.

# %%
rmse_1 = (np.sqrt(mean_squared_error(Y_Data, Y_pred)))

r2_1 = r2_score(Y_Data, Y_pred)


print("RMSE of LInear Regression for curved Relation :",rmse_1)

print("R2 of LInear Regression for curved Relation :",r2_1)
# Out:
# RMSE of LInear Regression for curved Relation : 15.908242501429998
# R2 of LInear Regression for curved Relation : 0.6386750054827146

# %% [markdown]
# #### How to address Under Fitting
#
# To overcome under-fitting, we need to increase the complexity of the model.

# %% [markdown]
# #### Lets create a Polynomial Regression of Degree 2

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial_features_2= PolynomialFeatures(degree=2)

x_poly = polynomial_features_2.fit_transform(X_Data)

# %%
x_poly
# Out:
# array([[ 1.        , -3.29215704, 10.83829796],
#        [ 1.        ,  0.79952837,  0.63924562],
#        [ 1.        , -0.93621395,  0.87649656],
#        [ 1.        , -4.7226796 , 22.30370258],
#        [ 1.        , -3.60267397, 12.97925974],
#        [ 1.        ,  4.93183364, 24.32298305],
#        [ 1.        , -0.85026525,  0.722951  ],
#        [ 1.        ,  2.45407162,  6.02246754],
#        [ 1.        ,  2.30965656,  5.3345134 ],
#        [ 1.        ,  0.76820449,  0.59013814],
#        [ 1.        ,  1.56786929,  2.4582141 ],
#        [ 1.        , -2.36282052,  5.58292081],
#        [ 1.        , -0.28311318,  0.08015307],
#        [ 1.        ,  1.63497495,  2.67314309],
#        [ 1.        ,  0.6684103 ,  0.44677233],
#        [ 1.        ,  0.99897702,  0.99795508],
#        [ 1.        , -2.48223722,  6.16150161],
#        [ 1.        ,  2.61547479,  6.84070838],
#        [ 1.        ,  1.0607969 ,  1.12529005],
# ...

# %%
Poly_Model_Deg_2 = LinearRegression()

Poly_Model_Deg_2.fit(x_poly, Y_Data)

y_poly_pred = Poly_Model_Deg_2.predict(x_poly)



rmse_2 = np.sqrt(mean_squared_error(Y_Data,y_poly_pred))

r2_2 = r2_score(Y_Data,y_poly_pred)

print("RMSE of LInear Regression for curved Relation :",rmse_2)

print("R2 of LInear Regression for curved Relation :",r2_2)
# Out:
# RMSE of LInear Regression for curved Relation : 10.120437473614711
# R2 of LInear Regression for curved Relation : 0.8537647164420812

# %% [markdown]
# #### Lets create a Polynomial Regression of Degree 3

# %%
polynomial_features_3= PolynomialFeatures(degree=3)

x_poly_3 = polynomial_features_3.fit_transform(X_Data)

# %%
x_poly_3.shape
# Out:
# (20, 4)

# %%
Poly_Model_Deg_3 = LinearRegression()

Poly_Model_Deg_3.fit(x_poly_3, Y_Data)

y_poly_pred_3 = Poly_Model_Deg_3.predict(x_poly_3)



rmse_3 = np.sqrt(mean_squared_error(Y_Data,y_poly_pred_3))

r2_3 = r2_score(Y_Data,y_poly_pred_3)

print("RMSE of Ploynomial Regression for curved Relation(3) :",rmse_3)

print("R2 of Ploynomial Regression for curved Relation (3) :",r2_3)
# Out:
# RMSE of Ploynomial Regression for curved Relation(3) : 3.449895507408724
# R2 of Ploynomial Regression for curved Relation (3) : 0.9830071790386679

# %% [markdown]
# ### Last Topic to Discuss : The Bias vs Variance trade-off
#
# Bias refers to the error due to the model’s simplistic assumptions in fitting the data. A high bias means that the model is unable to capture the patterns in the data and this results in under-fitting.
#
#
# Variance refers to the error due to the complex model trying to fit the data. High variance means the model passes through most of the data points and it results in over-fitting the data.
#
#
# The below picture summarizes our learning.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Thank You
