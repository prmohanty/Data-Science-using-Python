# %% [markdown]
# # Data Structures in Python
#
#
# Priyaranjan Mohanty

# %% [markdown]
# #### Before we explore the Data Structures in Python , lets understand the basic Data Types supported in Python.

# %% [markdown]
# ##### Numeric Data Type
#
#     int – holds signed integers
#
#     float- holds floating precision numbers
#
#
#
# Note : the Data Type of a Python variable can be enquired using the type() function

# %%
variable = 2019

print('Hello World !!','Welcome To Python',variable)
# Out:
# Hello World !! Welcome To Python 2019

# %%
# Defining an Integer variable 

Int_var = 10238

print( 'The variable Int_var contains the value :',Int_var , 
      ' and is of data type :',type(Int_var))
# Out:
# The variable Int_var contains the value : 10238  and is of data type : <class 'int'>

# %%
# Defining a floating point variable 

Float_var = 35.75

print( 'The variable Float_var contains the value :',Float_var , 
      ' and is of data type :',type(Float_var))
# Out:
# The variable Float_var contains the value : 35.75  and is of data type : <class 'float'>

# %%
Float_var = 12

print(type(Float_var))
# Out:
# <class 'int'>

# %% [markdown]
# #### Character / String Data Type

# %%
# Defining a String variable 

String_var = "This is a string Variable "

print( 'The variable String_var contains the value :',String_var , 
      ' and is of data type :',type(String_var))
# Out:
# The variable String_var contains the value : This is a string Variable   and is of data type : <class 'str'>

# %% [markdown]
# #### Boolean Data type

# %%
# Defining a Boolean variable ( variable with stored TRUE or FALSE )


Bool_var = True     # True is a Python keyword

print( 'The variable Bool_var contains the value :',Bool_var , 
      ' and is of data type :',type(Bool_var))

Bool_var = False

print( 'The variable Bool_var contains the value :',Bool_var , 
      ' and is of data type :',type(Bool_var))
# Out:
# The variable Bool_var contains the value : True  and is of data type : <class 'bool'>
# The variable Bool_var contains the value : False  and is of data type : <class 'bool'>

# %% [markdown]
# ## Data Structures in Python
#
# Data structure is a specific way of storing and organizing data in memory such that it can be retrieved and used in a most productive way.
#
# The data structure plays an important role in code optimization. The rate at which the data is stored or retrieved, from the memory, is quite important in algorithm optimization especially when huge amount of data are involved.

# %% [markdown]
# #### The following are the data structures in python that are mainly used for data science related projects.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1) Lists
#
#
# A list is a collection of homogeneous/heterogenous elements (int, float, string, etc.)

# %%
# Create an empty list

Empty_List = []

# %%
print(Empty_List)
# Out:
# []

# %%
len(Empty_List)
# Out:
# 0

# %%
# create a simple list

list_var = ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
# Display the content of the List ( whole list )

print(list_var)
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
len(list_var)
# Out:
# 9

# %% [markdown]
# #### Functions available for List data structure

# %%
# Find the data structure type of a list variable 

type(list_var)
# Out:
# list

# %%
# Find the count of elements in a list 

len(list_var)
# Out:
# 9

# %% [markdown]
# ##### Access the specific elements with in a List
#
#
# Note - The index in Python starts from 0 ( and not 1 )

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
# Accessing the first element in the list 

list_var[0]
# Out:
# 'hello'

# %%
# Accessing the 4th element in the list 

list_var[3]
# Out:
# 'you'

# %%
# Accessing the last element in the list 

list_var[-1]
# Out:
# 'are'

# %%
# Accessing the 3rd last element in the list 

list_var[-3]
# Out:
# 'how'

# %%
# Accessing the elements from 1st position till 5th position [approach - 1]

list_var[0:5]
# Out:
# ['hello', 'how', 'are', 'you', 1]

# %%
# Accessing the elements from 1st position till 5th position [approach - 2]

list_var[:5]
# Out:
# ['hello', 'how', 'are', 'you', 1]

# %%
# Accessing the elements from 3rd position till 5th position 

list_var[2:5]
# Out:
# ['are', 'you', 1]

# %%
# Accessing the elements from 4th position till end of the list

list_var[3:]
# Out:
# ['you', 1, 10, 'how', 'well', 'are']

# %% [markdown]
# ### Some advanced element accessing from a list
#
#
# Slicing
#
#     To get a specific set of elements from the list

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
list_var[0:8:2]
# Out:
# ['hello', 'are', 1, 'how']

# %%
# Accessing the elements which are in odd positions [approach 1]

list_var[0::2]
# Out:
# ['hello', 'are', 1, 'how', 'are']

# %%
# Accessing the elements which are in odd positions [approach 2]

list_var[::2]
# Out:
# ['hello', 'are', 1, 'how', 'are']

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
# Accessing the elements which are in even positions 

list_var[1::2]
# Out:
# ['how', 'you', 10, 'well']

# %%
# Accessing the elements in reverse order [approach 1]

list_var[-1::-1]
# Out:
# ['are', 'well', 'how', 10, 1, 'you', 'are', 'how', 'hello']

# %%
# Accessing the elements in reverse order [approach 2]

list_var[::-1]
# Out:
# ['are', 'well', 'how', 10, 1, 'you', 'are', 'how', 'hello']

# %% [markdown]
# ### Deleting the elements from a list

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
# Delete the whole List variable

del list_var

# %%
list_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-236-1da1c44c4c77> in <module>
# ----> 1 list_var
#
# NameError: name 'list_var' is not defined

# %%
# create a simple list

list_var = ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 1, 10, 'how', 'well', 'are']

# %%
# Delete a specific element of a list ( lets say the 5th element )

del list_var[4]

# %%
# Display the content of the list 

list_var
# Out:
# ['hello', 'how', 'are', 'you', 10, 'how', 'well', 'are']

# %%
# Delete a set of elements from the list ( using slicing )

del list_var[4:6]

# %%
list_var
# Out:
# ['hello', 'how', 'are', 'you', 'well', 'are']
